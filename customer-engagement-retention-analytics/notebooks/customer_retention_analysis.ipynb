# %% [markdown]
# # Customer Retention Analysis
# This notebook loads the project dataset, validates binary fields, enriches engagement and premium-risk segments, and calculates retention KPIs.

# %%
from pathlib import Path
import sys
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from data_cleaning import load_data
from analysis import calculate_kpis, segment_summary
df = load_data(ROOT / 'data' / 'European_Bank.csv')
df.head()

# %%
print('Shape:', df.shape)
print('Missing cells:', int(df.isna().sum().sum()))
print('Duplicate customer IDs:', int(df.CustomerId.duplicated().sum()))
calculate_kpis(df)

# %%
segment_summary(df)

# %%
display(df.groupby('ActivityLabel').Exited.agg(['size','mean']))
display(df.groupby('NumOfProducts').Exited.agg(['size','mean']))

# %% [markdown]
# ## Interpretation
# Use the results to prioritize inactive customers, especially those with high balances or only one product. Treat the results as descriptive evidence rather than causal estimates.
